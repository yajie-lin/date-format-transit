# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
hotel = pd.read_csv("/archive/hotel_booking.csv")
hotel.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
hotel.info()
hotel['arrival_date_month'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#日期處理#英文大寫月份#int與object處理

# %%
year = hotel.arrival_date_year.astype(str)
day=hotel.arrival_date_day_of_month.astype(str)
month=hotel.arrival_date_month
hotel.arrival=year+month+day
hotel["arrival"]
# Out:
# 0            2015July1
# 1            2015July1
# 2            2015July1
# 3            2015July1
# 4            2015July1
#               ...
# 119385    2017August30
# 119386    2017August31
# 119387    2017August31
# 119388    2017August31
# 119389    2017August29
# Name: arrival, Length: 119390, dtype: object

# %%
#法一
list(map(lambda x: datetime.datetime.strptime(x,'%Y%B%d').strftime('%Y/%m/%d'), hotel['arrival']))
# Out:
# ['2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/01',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
#  '2015/07/02',
# ...

# %%
#法二
pd.to_datetime(hotel['arrival'], format='%Y%B%d')
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-01
# 3        2015-07-01
# 4        2015-07-01
#             ...
# 119385   2017-08-30
# 119386   2017-08-31
# 119387   2017-08-31
# 119388   2017-08-31
# 119389   2017-08-29
# Name: arrival, Length: 119390, dtype: datetime64[ns]
